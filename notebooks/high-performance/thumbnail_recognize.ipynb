# %%
#Copyright 2018 Amazon.com, Inc. or its affiliates. All Rights Reserved.
#PDX-License-Identifier: MIT-0 (For details, see https://github.com/awsdocs/amazon-rekognition-developer-guide/blob/master/LICENSE-SAMPLECODE.)

import boto3

def detect_labels(photo, bucket):

     session = boto3.Session(profile_name='default')
     client = session.client('rekognition')

     response = client.detect_labels(Image={'S3Object':{'Bucket':bucket,'Name':photo}},
     MaxLabels=10,
     # Uncomment to use image properties and filtration settings
    #  Features=["GENERAL_LABELS", "IMAGE_PROPERTIES"],
    #  Settings={"GeneralLabels": {"LabelInclusionFilters":["Cat"]},
     # "ImageProperties": {"MaxDominantColors":10}}
     )

     print('Detected labels for ' + photo)
     print()
     for label in response['Labels']:
         print("Label: " + label['Name'])
         print("Confidence: " + str(label['Confidence']))
         print("Instances:")

         for instance in label['Instances']:
             print(" Bounding box")
             print(" Top: " + str(instance['BoundingBox']['Top']))
             print(" Left: " + str(instance['BoundingBox']['Left']))
             print(" Width: " + str(instance['BoundingBox']['Width']))
             print(" Height: " + str(instance['BoundingBox']['Height']))
             print(" Confidence: " + str(instance['Confidence']))
             print()

         print("Parents:")
         for parent in label['Parents']:
            print(" " + parent['Name'])

         print("Aliases:")
         for alias in label['Aliases']:
             print(" " + alias['Name'])

             print("Categories:")
         for category in label['Categories']:
             print(" " + category['Name'])
             print("----------")
             print()

     if "ImageProperties" in str(response):
         print("Background:")
         print(response["ImageProperties"]["Background"])
         print()
         print("Foreground:")
         print(response["ImageProperties"]["Foreground"])
         print()
         print("Quality:")
         print(response["ImageProperties"]["Quality"])
         print()

     return len(response['Labels'])

# photo = 'photo-name'
# bucket = 'thumbnailstoragebucket'
# label_count = detect_labels(photo, bucket)
# print("Labels detected: " + str(label_count))

bucket = 'thumbnailstoragebucket'
# list all objects in the bucket
s3 = boto3.resource('s3')
my_bucket = s3.Bucket(bucket)
file_keys = [obj.key for obj in my_bucket.objects.all()]
file_keys

key = file_keys[0]

label_count = detect_labels(key, bucket)
print("Labels detected: " + str(label_count))
# Out:
# ['-6Hce3HQRdg.jpg',
#  '-SJUlYmsBTo.jpg',
#  '0q7_RNY2mMI.jpg',
#  '1HRiXT6-z3U.jpg',
#  '1R97tphpD_M.jpg',
#  '1VZkiQUzITU.jpg',
#  '1Xqs2xF7X9g.jpg',
#  '1ci3l7pnfdk.jpg',
#  '1jFUxkAtnao.jpg',
#  '1kEFiocPLkI.jpg',
#  '1kbOwGzYGMk.jpg',
#  '22P7BSrBJgc.jpg',
#  '2N0jtSW9kwg.jpg',
#  '2YSqsuNO4gw.jpg',
#  '2Yueni460aM.jpg',
#  '3OpEN5AuXr0.jpg',
#  '3Pdamwkm7tE.jpg',
#  '3Ws3YptLmLQ.jpg',
#  '4eqi1cHUnQ0.jpg',
#  '4tfe10Q7oVE.jpg',
#  '4tpT1mbyfp0.jpg',
#  '55PqdwONcmA.jpg',
#  '5NZQoHebeEM.jpg',
#  '5j-R06GLvvU.jpg',
#  '5rGciSMJTTs.jpg',
#  '6PtiY-ev2qA.jpg',
#  '7NO-U_PPBH4.jpg',
#  '7NrNamzvWKU.jpg',
#  '7eM7pb5M5DU.jpg',
#  '7vQyrlW8ahw.jpg',
#  '7vlt0lLzzYQ.jpg',
#  '7wrNWDcv91c.jpg',
#  '85l5VbJbTtM.jpg',
#  '87IZlY0zl4A.jpg',
#  '87N24uZ2Fl4.jpg',
#  '8FSQZs3gqAE.jpg',
#  '8X1xYpPmKvA.jpg',
#  '8roROdbe4zA.jpg',
#  '8xhC1kNOHVM.jpg',
#  '90JP8FT7cag.jpg',
#  '9eD659Ynzxg.jpg',
#  '9na8UBoncy4.jpg',
#  'ABEdDreTjI4.jpg',
#  'ALvYKnyJyic.jpg',
#  'A_rK2tAIFLA.jpg',
#  'BDBVjSkMK54.jpg',
#  'Bh4qklXwsuU.jpg',
#  'C-RnREIwloQ.jpg',
#  'CAAkBiE4zzE.jpg',
#  'CAmQ5ODJJfA.jpg',
#  'CwwZFxH1W4c.jpg',
#  'DBkONFkdWSM.jpg',
#  'DHWYTwY0hiw.jpg',
#  'DdqCKmIiPMQ.jpg',
#  'Dt_wAmiScgA.jpg',
#  'Dyz9VzNSF60.jpg',
#  'EKgJ5ivg3AM.jpg',
#  'EiVyxCFZ__4.jpg',
#  'EkIvD-QpsVI.jpg',
#  'ErqDwJm3uBo.jpg',
#  'EshhbKj3ZGs.jpg',
#  'Ev5MFCg0O1I.jpg',
#  'FFEJSVf9RGM.jpg',
#  'FMEj9TfNF0Q.jpg',
#  'FTk7siPDkzg.jpg',
#  'FdzcuXmSUDM.jpg',
#  'FhqNGaA3fvY.jpg',
#  'FviEbCom1C0.jpg',
#  'FwC808ZLuAg.jpg',
#  'FyVeBELbtQQ.jpg',
#  'GRkwXphhv1E.jpg',
#  'GUWE7ibkfds.jpg',
#  'GW_YIJHBf0o.jpg',
#  'GnQMuS87gLw.jpg',
#  'GpMP6Nh3FvU.jpg',
#  'Grl7jjZj35s.jpg',
#  'GvAR2IVNNGM.jpg',
#  'HdVRyOX6S4A.jpg',
#  'HnE60IVm51E.jpg',
#  'HxcTfGDRlNs.jpg',
#  'JcpboMScfIY.jpg',
#  'JkhDqhzr1c8.jpg',
#  'K1MU5ysyPiI.jpg',
#  'KQMZexRllNs.jpg',
#  'KZbzIf_C6Y4.jpg',
#  'LhJABTrgM9A.jpg',
#  'MX2yhAGFISw.jpg',
#  'NCPNTsKBZS0.jpg',
#  'NLlU7HHCicU.jpg',
#  'NMDZcbkgpJA.jpg',
#  'NU4MgeOb-cc.jpg',
#  'Ngiq4T1GApM.jpg',
#  'NwVScJYnAIE.jpg',
#  'OA6F6liLnvc.jpg',
#  'OixC6jcXCwo.jpg',
#  'Ow51T-M6oYA.jpg',
#  'P9e762otDVY.jpg',
#  'PAQSsSzuDWA.jpg',
#  'PI7pYqMBri0.jpg',
#  'PkdtnVUm9ik.jpg',
#  'PnV8sYAEKuU.jpg',
#  'Q20RDmO8IFg.jpg',
#  'QINII0eeJxc.jpg',
#  'QiTpmA6ObKw.jpg',
#  'Que2myhwr48.jpg',
#  'RISUhOl6BSQ.jpg',
#  'RLrmQLbKJyA.jpg',
#  'RlVVCdBPKUU.jpg',
#  'Rloqr1aZSzk.jpg',
#  'Roy8XciLmsg.jpg',
#  'Sde_ir79gLk.jpg',
#  'SrKUkSfvfG0.jpg',
#  'T8tk29kgBsY.jpg',
#  'TCyuiJeyG2c.jpg',
#  'TG1nWScBfB4.jpg',
#  'TUvw_roAXAE.jpg',
#  'TftIoyO7ZqE.jpg',
#  'TyK9WiG8d3A.jpg',
#  'Tzvf0nIVLSI.jpg',
#  'UKlJqiGJBJ0.jpg',
#  'UNl9afe_PiY.jpg',
#  'UfMQfnkPU8Y.jpg',
#  'V10mnsWiu7M.jpg',
#  'VKa0U3CSTuA.jpg',
#  'VbY1g8arFro.jpg',
#  'VkNrXOJrCLg.jpg',
#  'W1FWVFOIOhs.jpg',
#  'WYmRD3532cs.jpg',
#  'XVuIMocTciY.jpg',
#  'XeL33iiANMA.jpg',
#  'XfcvX0P1b5g.jpg',
#  'Xfu7ke1tPYE.jpg',
#  'Xt8PWPgb9yQ.jpg',
#  'YFJN2bqE-sA.jpg',
#  'YNhlGx7e2nA.jpg',
#  'YhwTGqXFX8E.jpg',
#  'Z03BX5IEoZI.jpg',
#  'Z_y_zeql7pc.jpg',
#  'ZeVARqw6eKY.jpg',
#  'ZxU4YAdn28Y.jpg',
#  '_28b0P_6VvY.jpg',
#  '_6uSYhyFao4.jpg',
#  '_Kav2K1DVWo.jpg',
#  '_OzpODjTISc.jpg',
#  'a5kDs8I7brs.jpg',
#  'a9fi7fuT3fk.jpg',
#  'afv5y8lSJxM.jpg',
#  'bnEaTnkoOZI.jpg',
#  'bzSPO5Ofamw.jpg',
#  'c41rLpCpKnY.jpg',
#  'cKXUckMESmU.jpg',
#  'cNwOtYZ8s64.jpg',
#  'ccXB85tlAx8.jpg',
#  'coRX-idhVmI.jpg',
#  'dTL4t098wU8.jpg',
#  'eS_rEzKdzBA.jpg',
#  'fMWnaR5uJxQ.jpg',
#  'fac4A8lwr7A.jpg',
#  'faer0ew-Gzk.jpg',
#  'fbExvS0k_JY.jpg',
#  'fcuK1M7ddgU.jpg',
#  'ffDRJzLnGXc.jpg',
#  'hCsPV0eiqxg.jpg',
#  'hHWB0pm62i8.jpg',
#  'hKlUQeTRUDo.jpg',
#  'hVmss4uqUjs.jpg',
#  'hW7n4rh4HaY.jpg',
#  'hi3FHre1n68.jpg',
#  'hiKj1C3Bob8.jpg',
#  'hxc4lYy8OJ4.jpg',
#  'i9InAbpM7mU.jpg',
#  'iNf7mAtePP4.jpg',
#  'izm72oI-GOA.jpg',
#  'j7aBITkr3W4.jpg',
#  'jnrVd2BARx4.jpg',
#  'k-6Qn7V20B0.jpg',
#  'k_B3a2cCqo0.jpg',
#  'lAguD4gBmSI.jpg',
#  'lL0CkSNUIG8.jpg',
#  'lQLHkDS9BOw.jpg',
#  'n1xJs-FwffQ.jpg',
#  'nizcZmU8dC0.jpg',
#  'nqHSdjN9Vzs.jpg',
#  'nsl5i4N5XAA.jpg',
#  'nwwhd7VzFLI.jpg',
#  'o_FCDAAvfy4.jpg',
#  'owWUyOm7SBE.jpg',
#  'p9LWzr-_ibI.jpg',
#  'pEUcdefk5_E.jpg',
#  'pK7eDBd5mQc.jpg',
#  'pPNZ4c_M98w.jpg',
#  'pl20NdwAs3k.jpg',
#  'q-1HikE4b54.jpg',
#  'q9XmXad_wmo.jpg',
#  'r5vXeL3TrB4.jpg',
#  'rKZeUJeYxig.jpg',
#  'sB07b99vWig.jpg',
#  'sYWPXPOQ-vA.jpg',
#  'scy3-vgov0w.jpg',
#  'snWvNkJCCs8.jpg',
#  't4ErpPU-llI.jpg',
#  'tExo3ovEBWQ.jpg',
#  'tF0dCNxfYHk.jpg',
#  'tMMX7VaaR9U.jpg',
#  'tTCZB-dZuWo.jpg',
#  'tjEG6qDl8zo.jpg',
#  'tmSewYqFhm4.jpg',
#  'tywFg2FAr9c.jpg',
#  'u2-QGh0DkMI.jpg',
#  'u2CmaqMUD30.jpg',
#  'uB9CDEp1mMo.jpg',
#  'uEooWjWk68o.jpg',
#  'urMN-BM62Qk.jpg',
#  'v3uihCgrUQM.jpg',
#  'vboQOQwifwg.jpg',
#  'wAUGFiLrplg.jpg',
#  'wCUcypJU658.jpg',
#  'wJc6skYUUEY.jpg',
#  'whQ8UBoz-To.jpg',
#  'wi1B4fuSFpA.jpg',
#  'wszAFgiwQOI.jpg',
#  'wwpOuSy5Z5A.jpg',
#  'xEeyLDTAkK8.jpg',
#  'xQqGIZUFAw0.jpg',
#  'y93Oifkrf4c.jpg',
#  'zLd9Q6687Cg.jpg',
#  'zr64hUY6qlg.jpg']

# %%
bucket = 'thumbnailstoragebucket'
# list all objects in the bucket
s3 = boto3.resource('s3')
my_bucket = s3.Bucket(bucket)
file_keys = [obj.key for obj in my_bucket.objects.all()]
file_keys
# Out:
# ['-6Hce3HQRdg.jpg',
#  '-SJUlYmsBTo.jpg',
#  '0q7_RNY2mMI.jpg',
#  '1HRiXT6-z3U.jpg',
#  '1R97tphpD_M.jpg',
#  '1VZkiQUzITU.jpg',
#  '1Xqs2xF7X9g.jpg',
#  '1ci3l7pnfdk.jpg',
#  '1jFUxkAtnao.jpg',
#  '1kEFiocPLkI.jpg',
#  '1kbOwGzYGMk.jpg',
#  '22P7BSrBJgc.jpg',
#  '2N0jtSW9kwg.jpg',
#  '2YSqsuNO4gw.jpg',
#  '2Yueni460aM.jpg',
#  '3OpEN5AuXr0.jpg',
#  '3Pdamwkm7tE.jpg',
#  '3Ws3YptLmLQ.jpg',
#  '4eqi1cHUnQ0.jpg',
#  '4tfe10Q7oVE.jpg',
#  '4tpT1mbyfp0.jpg',
#  '55PqdwONcmA.jpg',
#  '5NZQoHebeEM.jpg',
#  '5j-R06GLvvU.jpg',
#  '5rGciSMJTTs.jpg',
#  '6PtiY-ev2qA.jpg',
#  '7NO-U_PPBH4.jpg',
#  '7NrNamzvWKU.jpg',
#  '7eM7pb5M5DU.jpg',
#  '7vQyrlW8ahw.jpg',
#  '7vlt0lLzzYQ.jpg',
#  '7wrNWDcv91c.jpg',
#  '85l5VbJbTtM.jpg',
#  '87IZlY0zl4A.jpg',
#  '87N24uZ2Fl4.jpg',
#  '8FSQZs3gqAE.jpg',
#  '8X1xYpPmKvA.jpg',
#  '8roROdbe4zA.jpg',
#  '8xhC1kNOHVM.jpg',
#  '90JP8FT7cag.jpg',
#  '9eD659Ynzxg.jpg',
#  '9na8UBoncy4.jpg',
#  'ABEdDreTjI4.jpg',
#  'ALvYKnyJyic.jpg',
#  'A_rK2tAIFLA.jpg',
#  'BDBVjSkMK54.jpg',
#  'Bh4qklXwsuU.jpg',
#  'C-RnREIwloQ.jpg',
#  'CAAkBiE4zzE.jpg',
#  'CAmQ5ODJJfA.jpg',
#  'CwwZFxH1W4c.jpg',
#  'DBkONFkdWSM.jpg',
#  'DHWYTwY0hiw.jpg',
#  'DdqCKmIiPMQ.jpg',
#  'Dt_wAmiScgA.jpg',
#  'Dyz9VzNSF60.jpg',
#  'EKgJ5ivg3AM.jpg',
#  'EiVyxCFZ__4.jpg',
#  'EkIvD-QpsVI.jpg',
#  'ErqDwJm3uBo.jpg',
#  'EshhbKj3ZGs.jpg',
#  'Ev5MFCg0O1I.jpg',
#  'FFEJSVf9RGM.jpg',
#  'FMEj9TfNF0Q.jpg',
#  'FTk7siPDkzg.jpg',
#  'FdzcuXmSUDM.jpg',
#  'FhqNGaA3fvY.jpg',
#  'FviEbCom1C0.jpg',
#  'FwC808ZLuAg.jpg',
#  'FyVeBELbtQQ.jpg',
#  'GRkwXphhv1E.jpg',
#  'GUWE7ibkfds.jpg',
#  'GW_YIJHBf0o.jpg',
#  'GnQMuS87gLw.jpg',
#  'GpMP6Nh3FvU.jpg',
#  'Grl7jjZj35s.jpg',
#  'GvAR2IVNNGM.jpg',
#  'HdVRyOX6S4A.jpg',
#  'HnE60IVm51E.jpg',
#  'HxcTfGDRlNs.jpg',
#  'JcpboMScfIY.jpg',
#  'JkhDqhzr1c8.jpg',
#  'K1MU5ysyPiI.jpg',
#  'KQMZexRllNs.jpg',
#  'KZbzIf_C6Y4.jpg',
#  'LhJABTrgM9A.jpg',
#  'MX2yhAGFISw.jpg',
#  'NCPNTsKBZS0.jpg',
#  'NLlU7HHCicU.jpg',
#  'NMDZcbkgpJA.jpg',
#  'NU4MgeOb-cc.jpg',
#  'Ngiq4T1GApM.jpg',
#  'NwVScJYnAIE.jpg',
#  'OA6F6liLnvc.jpg',
#  'OixC6jcXCwo.jpg',
#  'Ow51T-M6oYA.jpg',
#  'P9e762otDVY.jpg',
#  'PAQSsSzuDWA.jpg',
#  'PI7pYqMBri0.jpg',
#  'PkdtnVUm9ik.jpg',
#  'PnV8sYAEKuU.jpg',
#  'Q20RDmO8IFg.jpg',
#  'QINII0eeJxc.jpg',
#  'QiTpmA6ObKw.jpg',
#  'Que2myhwr48.jpg',
#  'RISUhOl6BSQ.jpg',
#  'RLrmQLbKJyA.jpg',
#  'RlVVCdBPKUU.jpg',
#  'Rloqr1aZSzk.jpg',
#  'Roy8XciLmsg.jpg',
#  'Sde_ir79gLk.jpg',
#  'SrKUkSfvfG0.jpg',
#  'T8tk29kgBsY.jpg',
#  'TCyuiJeyG2c.jpg',
#  'TG1nWScBfB4.jpg',
#  'TUvw_roAXAE.jpg',
#  'TftIoyO7ZqE.jpg',
#  'TyK9WiG8d3A.jpg',
#  'Tzvf0nIVLSI.jpg',
#  'UKlJqiGJBJ0.jpg',
#  'UNl9afe_PiY.jpg',
#  'UfMQfnkPU8Y.jpg',
#  'V10mnsWiu7M.jpg',
#  'VKa0U3CSTuA.jpg',
#  'VbY1g8arFro.jpg',
#  'VkNrXOJrCLg.jpg',
#  'W1FWVFOIOhs.jpg',
#  'WYmRD3532cs.jpg',
#  'XVuIMocTciY.jpg',
#  'XeL33iiANMA.jpg',
#  'XfcvX0P1b5g.jpg',
#  'Xfu7ke1tPYE.jpg',
#  'Xt8PWPgb9yQ.jpg',
#  'YFJN2bqE-sA.jpg',
#  'YNhlGx7e2nA.jpg',
#  'YhwTGqXFX8E.jpg',
#  'Z03BX5IEoZI.jpg',
#  'Z_y_zeql7pc.jpg',
#  'ZeVARqw6eKY.jpg',
#  'ZxU4YAdn28Y.jpg',
#  '_28b0P_6VvY.jpg',
#  '_6uSYhyFao4.jpg',
#  '_Kav2K1DVWo.jpg',
#  '_OzpODjTISc.jpg',
#  'a5kDs8I7brs.jpg',
#  'a9fi7fuT3fk.jpg',
#  'afv5y8lSJxM.jpg',
#  'bnEaTnkoOZI.jpg',
#  'bzSPO5Ofamw.jpg',
#  'c41rLpCpKnY.jpg',
#  'cKXUckMESmU.jpg',
#  'cNwOtYZ8s64.jpg',
#  'ccXB85tlAx8.jpg',
#  'coRX-idhVmI.jpg',
#  'dTL4t098wU8.jpg',
#  'eS_rEzKdzBA.jpg',
#  'fMWnaR5uJxQ.jpg',
#  'fac4A8lwr7A.jpg',
#  'faer0ew-Gzk.jpg',
#  'fbExvS0k_JY.jpg',
#  'fcuK1M7ddgU.jpg',
#  'ffDRJzLnGXc.jpg',
#  'hCsPV0eiqxg.jpg',
#  'hHWB0pm62i8.jpg',
#  'hKlUQeTRUDo.jpg',
#  'hVmss4uqUjs.jpg',
#  'hW7n4rh4HaY.jpg',
#  'hi3FHre1n68.jpg',
#  'hiKj1C3Bob8.jpg',
#  'hxc4lYy8OJ4.jpg',
#  'i9InAbpM7mU.jpg',
#  'iNf7mAtePP4.jpg',
#  'izm72oI-GOA.jpg',
#  'j7aBITkr3W4.jpg',
#  'jnrVd2BARx4.jpg',
#  'k-6Qn7V20B0.jpg',
#  'k_B3a2cCqo0.jpg',
#  'lAguD4gBmSI.jpg',
#  'lL0CkSNUIG8.jpg',
#  'lQLHkDS9BOw.jpg',
#  'n1xJs-FwffQ.jpg',
#  'nizcZmU8dC0.jpg',
#  'nqHSdjN9Vzs.jpg',
#  'nsl5i4N5XAA.jpg',
#  'nwwhd7VzFLI.jpg',
#  'o_FCDAAvfy4.jpg',
#  'owWUyOm7SBE.jpg',
#  'p9LWzr-_ibI.jpg',
#  'pEUcdefk5_E.jpg',
#  'pK7eDBd5mQc.jpg',
#  'pPNZ4c_M98w.jpg',
#  'pl20NdwAs3k.jpg',
#  'q-1HikE4b54.jpg',
#  'q9XmXad_wmo.jpg',
#  'r5vXeL3TrB4.jpg',
#  'rKZeUJeYxig.jpg',
#  'sB07b99vWig.jpg',
#  'sYWPXPOQ-vA.jpg',
#  'scy3-vgov0w.jpg',
#  'snWvNkJCCs8.jpg',
#  't4ErpPU-llI.jpg',
#  'tExo3ovEBWQ.jpg',
#  'tF0dCNxfYHk.jpg',
#  'tMMX7VaaR9U.jpg',
#  'tTCZB-dZuWo.jpg',
#  'tjEG6qDl8zo.jpg',
#  'tmSewYqFhm4.jpg',
#  'tywFg2FAr9c.jpg',
#  'u2-QGh0DkMI.jpg',
#  'u2CmaqMUD30.jpg',
#  'uB9CDEp1mMo.jpg',
#  'uEooWjWk68o.jpg',
#  'urMN-BM62Qk.jpg',
#  'v3uihCgrUQM.jpg',
#  'vboQOQwifwg.jpg',
#  'wAUGFiLrplg.jpg',
#  'wCUcypJU658.jpg',
#  'wJc6skYUUEY.jpg',
#  'whQ8UBoz-To.jpg',
#  'wi1B4fuSFpA.jpg',
#  'wszAFgiwQOI.jpg',
#  'wwpOuSy5Z5A.jpg',
#  'xEeyLDTAkK8.jpg',
#  'xQqGIZUFAw0.jpg',
#  'y93Oifkrf4c.jpg',
#  'zLd9Q6687Cg.jpg',
#  'zr64hUY6qlg.jpg']

# %%
key = file_keys[0]

label_count = detect_labels(key, bucket)
print("Labels detected: " + str(label_count))
# Out:
# Detected labels for -6Hce3HQRdg.jpg
#
# Label: Finger
# Confidence: 100.0
# Instances:
# Parents:
#  Body Part
#  Hand
#  Person
# Aliases:
#  Person Description
# ----------
#
# Label: Hand
# Confidence: 100.0
# Instances:
# Parents:
#  Body Part
#  Person
# Aliases:
#  Person Description
# ----------
#
# Label: Person
# Confidence: 100.0
# Instances:
#  Bounding box
#  Top: 0.11648030579090118
#  Left: 0.36097201704978943
#  Width: 0.5079036951065063
#  Height: 0.8792803287506104
#  Confidence: 99.38634490966797
#
#  Bounding box
#  Top: 0.35253965854644775
#  Left: 0.8651240468025208
#  Width: 0.06733503192663193
#  Height: 0.2510548532009125
#  Confidence: 75.33165740966797
#
#  Bounding box
#  Top: 0.3690246641635895
#  Left: 0.6867601871490479
#  Width: 0.08256621658802032
#  Height: 0.19534949958324432
#  Confidence: 70.61103057861328
#
#  Bounding box
#  Top: 0.37534523010253906
#  Left: 0.7796684503555298
#  Width: 0.06695465743541718
#  Height: 0.19424082338809967
#  Confidence: 67.91510009765625
#
# Parents:
# Aliases:
#  Human
# Categories:
#  Person Description
# ----------
#
# Label: Photography
# Confidence: 99.9969482421875
# Instances:
# Parents:
# Aliases:
#  Photo
# Categories:
#  Hobbies and Interests
# ----------
#
# Label: Portrait
# Confidence: 99.93692016601562
# Instances:
# Parents:
#  Face
#  Head
#  Person
#  Photography
# Aliases:
#  Hobbies and Interests
# ----------
#
# Label: Adult
# Confidence: 99.38634490966797
# Instances:
#  Bounding box
#  Top: 0.11648030579090118
#  Left: 0.36097201704978943
#  Width: 0.5079036951065063
#  Height: 0.8792803287506104
#  Confidence: 99.38634490966797
#
# Parents:
#  Person
# Aliases:
#  Person Description
# ----------
#
# Label: Male
# Confidence: 99.38634490966797
# Instances:
#  Bounding box
#  Top: 0.11648030579090118
#  Left: 0.36097201704978943
#  Width: 0.5079036951065063
#  Height: 0.8792803287506104
#  Confidence: 99.38634490966797
#
# Parents:
#  Person
# Aliases:
#  Person Description
# ----------
#
# Label: Man
# Confidence: 99.38634490966797
# Instances:
#  Bounding box
#  Top: 0.11648030579090118
#  Left: 0.36097201704978943
#  Width: 0.5079036951065063
#  Height: 0.8792803287506104
#  Confidence: 99.38634490966797
#
# Parents:
#  Adult
#  Male
#  Person
# Aliases:
#  Person Description
# ----------
#
# Label: Advertisement
# Confidence: 97.43965148925781
# Instances:
# Parents:
# Aliases:
#  Text and Documents
# ----------
#
# Label: Poster
# Confidence: 93.45044708251953
# Instances:
# Parents:
#  Advertisement
# Aliases:
#  Brochure
# Categories:
#  Flyer
# Categories:
#  Furniture and Furnishings
# ----------
#
# Labels detected: 10
